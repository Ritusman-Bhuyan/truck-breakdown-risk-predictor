# %% [markdown]
# INSTALLING TENSORFLOW

# %%
# !pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\rkbhuyan\appdata\local\programs\python\python313\lib\site-packages (2.21.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\rkbhuyan\appdata\local\programs\python\python313\lib\site-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\rkbhuyan\appdata\local\programs\python\python313\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=25.9.23 in c:\users\rkbhuyan\appdata\local\programs\python\python313\lib\site-packages (from tensorflow) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\rkbhuyan\appdata\local\programs\python\python313\lib\site-packages (from tensorflow) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in c:\users\rkbhuyan\appdata\local\programs\python\python313\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\rkbhuyan\appdata\local\programs\python\python313\lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in c:\users\rkbhuyan\appdata\local\programs\python\python313\lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\users\rkbhuyan\appdata\local\programs\python\python313\lib\site-packages (from tensorflow) (26.0)
# Requirement already satisfied: protobuf<8.0.0,>=6.31.1 in c:\users\rkbhuyan\appdata\local\programs\python\python313\lib\site-packages (from tensorflow) (7.34.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\rkbhuyan\appdata\local\programs\python\python313\lib\site-packages (from tensorflow) (2.33.1)
# Requirement already satisfied: setuptools in c:\users\rkbhuyan\appdata\local\programs\python\python313\lib\site-packages (from tensorflow) (81.0.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\rkbhuyan\appdata\local\programs\python\python313\lib\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\rkbhuyan\appdata\local\programs\python\python313\lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in c:\users\rkbhuyan\appdata\local\programs\python\python313\lib\site-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\rkbhuyan\appdata\local\programs\python\python313\lib\site-packages (from tensorflow) (2.1.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\rkbhuyan\appdata\local\programs\python\python313\lib\site-packages (from tensorflow) (1.80.0)
# Requirement already satisfied: keras>=3.12.0 in c:\users\rkbhuyan\appdata\local\programs\python\python313\lib\site-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\rkbhuyan\appdata\local\programs\python\python313\lib\site-packages (from tensorflow) (2.4.4)
# Requirement already satisfied: h5py<3.15.0,>=3.11.0 in c:\users\rkbhuyan\appdata\local\programs\python\python313\lib\site-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in c:\users\rkbhuyan\appdata\local\programs\python\python313\lib\site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\rkbhuyan\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\rkbhuyan\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.11)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\rkbhuyan\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.6.3)
# Requirement already satisfied: certifi>=2023.5.7 in c:\users\rkbhuyan\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2026.2.25)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\rkbhuyan\appdata\local\programs\python\python313\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.46.3)
# Requirement already satisfied: rich in c:\users\rkbhuyan\appdata\local\programs\python\python313\lib\site-packages (from keras>=3.12.0->tensorflow) (15.0.0)
# Requirement already satisfied: namex in c:\users\rkbhuyan\appdata\local\programs\python\python313\lib\site-packages (from keras>=3.12.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in c:\users\rkbhuyan\appdata\local\programs\python\python313\lib\site-packages (from keras>=3.12.0->tensorflow) (0.19.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\rkbhuyan\appdata\local\programs\python\python313\lib\site-packages (from rich->keras>=3.12.0->tensorflow) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\rkbhuyan\appdata\local\programs\python\python313\lib\site-packages (from rich->keras>=3.12.0->tensorflow) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\rkbhuyan\appdata\local\programs\python\python313\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.12.0->tensorflow) (0.1.2)
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np 
import tensorflow as tf

# %% [markdown]
# PREPARING THE DATASET

# %%
df1 = pd.read_csv('data-with-concern.csv')  # importing the dataset for the tire breakdown reasons
df1
# Out:
#                description material_name  tonnage_percentage  speed  \
# 0           ARO/RIN/BIRLOS         INPIT                98.4   18.0
# 1           ARO/RIN/BIRLOS         INPIT                98.4   21.6
# 2           ARO/RIN/BIRLOS         INPIT                98.4   21.6
# 3           ARO/RIN/BIRLOS         INPIT                98.4   25.2
# 4           ARO/RIN/BIRLOS         INPIT                98.4   25.2
# ...                    ...           ...                 ...    ...
# 29142  ROTACION DE LLANTAS      TEPETATE                 NaN   39.6
# 29143  ROTACION DE LLANTAS      TEPETATE                 NaN   43.2
# 29144  ROTACION DE LLANTAS      TEPETATE                 NaN   43.2
# 29145  ROTACION DE LLANTAS      TEPETATE                 NaN   43.2
# 29146  ROTACION DE LLANTAS      TEPETATE                 NaN   46.8
#
#       road_category  gradient
# 0              Lift         0
# 1              Lift         2
# 2              Lift         7
# 3              Lift         0
# 4              Lift         2
# ...             ...       ...
# 29142       Surface        12
# 29143          Lift         8
# 29144       Surface        -1
# 29145       Surface        12
# 29146       Surface        -1
#
# [29147 rows x 6 columns]

# %%
df1 = df1[['description','tonnage_percentage','speed','road_category','gradient']]  # Extracting the neccessary columns
df1
# Out:
#                description  tonnage_percentage  speed road_category  gradient
# 0           ARO/RIN/BIRLOS                98.4   18.0          Lift         0
# 1           ARO/RIN/BIRLOS                98.4   21.6          Lift         2
# 2           ARO/RIN/BIRLOS                98.4   21.6          Lift         7
# 3           ARO/RIN/BIRLOS                98.4   25.2          Lift         0
# 4           ARO/RIN/BIRLOS                98.4   25.2          Lift         2
# ...                    ...                 ...    ...           ...       ...
# 29142  ROTACION DE LLANTAS                 NaN   39.6       Surface        12
# 29143  ROTACION DE LLANTAS                 NaN   43.2          Lift         8
# 29144  ROTACION DE LLANTAS                 NaN   43.2       Surface        -1
# 29145  ROTACION DE LLANTAS                 NaN   43.2       Surface        12
# 29146  ROTACION DE LLANTAS                 NaN   46.8       Surface        -1
#
# [29147 rows x 5 columns]

# %%
df2 = pd.read_csv('data-without-concern.csv')  # Importing the dataset for no tire breakdown reasons
df2
# Out:
#        description material_name  tonnage_percentage  speed road_category  \
# 0              A/C         INPIT              100.00    3.6          Dump
# 1              A/C         INPIT              100.00   18.0          Dump
# 2              A/C    LIXIVIABLE               94.89   10.8          Lift
# 3              A/C    LIXIVIABLE               94.89   14.4          Lift
# 4              A/C    LIXIVIABLE               94.89   14.4          Lift
# ...            ...           ...                 ...    ...           ...
# 29681  TRANSMISION      TEPETATE                 NaN   25.2          Lift
# 29682  TRANSMISION      TEPETATE                 NaN   28.8          Lift
# 29683  TRANSMISION      TEPETATE                 NaN   32.4          Lift
# 29684  TRANSMISION      TEPETATE                 NaN   36.0          Lift
# 29685  TRANSMISION      TEPETATE                 NaN   46.8          Lift
#
#        gradient
# 0            -4
# 1            -4
# 2             5
# 3             4
# 4             5
# ...         ...
# 29681         5
# 29682        -6
# 29683        -6
# 29684        -6
# 29685        -6
#
# [29686 rows x 6 columns]

# %%
df2 = df2[['description','tonnage_percentage','speed','road_category','gradient']]  # Extracting the neccessary columns
df2
# Out:
#        description  tonnage_percentage  speed road_category  gradient
# 0              A/C              100.00    3.6          Dump        -4
# 1              A/C              100.00   18.0          Dump        -4
# 2              A/C               94.89   10.8          Lift         5
# 3              A/C               94.89   14.4          Lift         4
# 4              A/C               94.89   14.4          Lift         5
# ...            ...                 ...    ...           ...       ...
# 29681  TRANSMISION                 NaN   25.2          Lift         5
# 29682  TRANSMISION                 NaN   28.8          Lift        -6
# 29683  TRANSMISION                 NaN   32.4          Lift        -6
# 29684  TRANSMISION                 NaN   36.0          Lift        -6
# 29685  TRANSMISION                 NaN   46.8          Lift        -6
#
# [29686 rows x 5 columns]

# %%
df1['description'] = 'Yes'  # Replacing the tire breakdown reasons description by a single boolean variable (which will be encoded later on while training our model)
df1
# Out:
#       description  tonnage_percentage  speed road_category  gradient
# 0             Yes                98.4   18.0          Lift         0
# 1             Yes                98.4   21.6          Lift         2
# 2             Yes                98.4   21.6          Lift         7
# 3             Yes                98.4   25.2          Lift         0
# 4             Yes                98.4   25.2          Lift         2
# ...           ...                 ...    ...           ...       ...
# 29142         Yes                 NaN   39.6       Surface        12
# 29143         Yes                 NaN   43.2          Lift         8
# 29144         Yes                 NaN   43.2       Surface        -1
# 29145         Yes                 NaN   43.2       Surface        12
# 29146         Yes                 NaN   46.8       Surface        -1
#
# [29147 rows x 5 columns]

# %%
df2['description'] = 'No'  # Replacing the non tire breakdown reasons description by a single boolean variable (which will be encoded later on while training our model)
df2
# Out:
#       description  tonnage_percentage  speed road_category  gradient
# 0              No              100.00    3.6          Dump        -4
# 1              No              100.00   18.0          Dump        -4
# 2              No               94.89   10.8          Lift         5
# 3              No               94.89   14.4          Lift         4
# 4              No               94.89   14.4          Lift         5
# ...           ...                 ...    ...           ...       ...
# 29681          No                 NaN   25.2          Lift         5
# 29682          No                 NaN   28.8          Lift        -6
# 29683          No                 NaN   32.4          Lift        -6
# 29684          No                 NaN   36.0          Lift        -6
# 29685          No                 NaN   46.8          Lift        -6
#
# [29686 rows x 5 columns]

# %%
df = pd.concat([df1, df2], ignore_index=True)  # Concating all the tire breakdown and non tire breakdown reasons to prepare final dataset
df
# Out:
#       description  tonnage_percentage  speed road_category  gradient
# 0             Yes                98.4   18.0          Lift         0
# 1             Yes                98.4   21.6          Lift         2
# 2             Yes                98.4   21.6          Lift         7
# 3             Yes                98.4   25.2          Lift         0
# 4             Yes                98.4   25.2          Lift         2
# ...           ...                 ...    ...           ...       ...
# 58828          No                 NaN   25.2          Lift         5
# 58829          No                 NaN   28.8          Lift        -6
# 58830          No                 NaN   32.4          Lift        -6
# 58831          No                 NaN   36.0          Lift        -6
# 58832          No                 NaN   46.8          Lift        -6
#
# [58833 rows x 5 columns]

# %%
df = df[(df['road_category'] == 'Surface')]  # Filtering our dataset on Surface tye road categories

# %% [markdown]
# FINAL DATASET

# %%
df
# Out:
#       description  tonnage_percentage  speed road_category  gradient
# 274           Yes               93.37   25.2       Surface        -1
# 275           Yes               93.37   36.0       Surface        -1
# 276           Yes               93.37   39.6       Surface        -1
# 278           Yes               98.42    3.6       Surface         0
# 281           Yes               98.42    7.2       Surface        -8
# ...           ...                 ...    ...           ...       ...
# 58728          No              100.00   18.0       Surface         1
# 58730          No              100.00   21.6       Surface         0
# 58823          No                 NaN   18.0       Surface         0
# 58824          No                 NaN   18.0       Surface         1
# 58826          No                 NaN   21.6       Surface         0
#
# [25830 rows x 5 columns]

# %%
df = df.fillna(0)  # Replacing all Null values by 0
df
# Out:
#       description  tonnage_percentage  speed road_category  gradient
# 274           Yes               93.37   25.2       Surface        -1
# 275           Yes               93.37   36.0       Surface        -1
# 276           Yes               93.37   39.6       Surface        -1
# 278           Yes               98.42    3.6       Surface         0
# 281           Yes               98.42    7.2       Surface        -8
# ...           ...                 ...    ...           ...       ...
# 58728          No              100.00   18.0       Surface         1
# 58730          No              100.00   21.6       Surface         0
# 58823          No                0.00   18.0       Surface         0
# 58824          No                0.00   18.0       Surface         1
# 58826          No                0.00   21.6       Surface         0
#
# [25830 rows x 5 columns]

# %% [markdown]
# DIVIDING THE FEATURE AND TARGET DATA

# %%
feature = df.drop(['description','road_category'], axis=1)  # Dividing feature and target columns
feature
# Out:
#        tonnage_percentage  speed  gradient
# 274                 93.37   25.2        -1
# 275                 93.37   36.0        -1
# 276                 93.37   39.6        -1
# 278                 98.42    3.6         0
# 281                 98.42    7.2        -8
# ...                   ...    ...       ...
# 58728              100.00   18.0         1
# 58730              100.00   21.6         0
# 58823                0.00   18.0         0
# 58824                0.00   18.0         1
# 58826                0.00   21.6         0
#
# [25830 rows x 3 columns]

# %%
X = feature.values  # Converting our features into a numpy array
X
# Out:
# array([[93.37, 25.2 , -1.  ],
#        [93.37, 36.  , -1.  ],
#        [93.37, 39.6 , -1.  ],
#        ...,
#        [ 0.  , 18.  ,  0.  ],
#        [ 0.  , 18.  ,  1.  ],
#        [ 0.  , 21.6 ,  0.  ]], shape=(25830, 3))

# %% [markdown]
# SCALING THE FEATURE VALUES

# %%
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\rkbhuyan\appdata\local\programs\python\python313\lib\site-packages (1.8.0)
# Requirement already satisfied: numpy>=1.24.1 in c:\users\rkbhuyan\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn) (2.4.4)
# Requirement already satisfied: scipy>=1.10.0 in c:\users\rkbhuyan\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn) (1.17.1)
# Requirement already satisfied: joblib>=1.3.0 in c:\users\rkbhuyan\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\rkbhuyan\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn) (3.6.0)
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import sklearn

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
X = scaler.fit_transform(X)  # Scaling our feature values
X
# Out:
# array([[-0.07906274,  0.41884869,  0.24633852],
#        [-0.07906274,  1.4734557 ,  0.24633852],
#        [-0.07906274,  1.82499137,  0.24633852],
#        ...,
#        [-4.27143418, -0.28422264,  0.37412091],
#        [-4.27143418, -0.28422264,  0.50190329],
#        [-4.27143418,  0.06731302,  0.37412091]], shape=(25830, 3))

# %% [markdown]
# ENCODING OUR FEATURE VALUES INTO YES/NO

# %%
from sklearn.preprocessing import LabelEncoder, StandardScaler

# %%
label_encoder = LabelEncoder()

# %%
df
# Out:
#       description  tonnage_percentage  speed road_category  gradient
# 274           Yes               93.37   25.2       Surface        -1
# 275           Yes               93.37   36.0       Surface        -1
# 276           Yes               93.37   39.6       Surface        -1
# 278           Yes               98.42    3.6       Surface         0
# 281           Yes               98.42    7.2       Surface        -8
# ...           ...                 ...    ...           ...       ...
# 58728          No              100.00   18.0       Surface         1
# 58730          No              100.00   21.6       Surface         0
# 58823          No                0.00   18.0       Surface         0
# 58824          No                0.00   18.0       Surface         1
# 58826          No                0.00   21.6       Surface         0
#
# [25830 rows x 5 columns]

# %%
df["description"]
# Out:
# 274      Yes
# 275      Yes
# 276      Yes
# 278      Yes
# 281      Yes
#         ...
# 58728     No
# 58730     No
# 58823     No
# 58824     No
# 58826     No
# Name: description, Length: 25830, dtype: str

# %%
Y = label_encoder.fit_transform(df['description'])  # Encoding our boolean variable: YES-1, NO-0
Y
# Out:
# array([1, 1, 1, ..., 0, 0, 0], shape=(25830,))

# %% [markdown]
# SPLITTING OUR MODEL FOR TRAINING AND TESTING

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42, stratify=Y)  # Splitting our dataset into 80% testing and 20% testing datasets

# %% [markdown]
# BUILDING OUR ANN MODEL FOR RISK PREDICTION

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Dense, Dropout, Input
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
model = tf.keras.models.Sequential()  # Creating a sequential neural network model

# %%
model.add(tf.keras.Input(shape = (3,)))   # input layer

# %%
model.add(tf.keras.layers.Dense(units = 32, activation = 'relu'))  # 1st hidden layer
model.add(Dropout(0.1))

# %%
model.add(tf.keras.layers.Dense(units = 12, activation = 'relu'))  # 2nd hidden layer

# %%
model.add(tf.keras.layers.Dense(units = 1, activation = 'sigmoid'))  # output layer

# %%
model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics=['accuracy'])  # Compiling our model
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %%
early_stop = EarlyStopping(
    monitor='val_loss',
    patience=5,   # stop if no improvement for 5 epochs
    restore_best_weights=True
)

# %%
history = model.fit(
    X_train, Y_train,
    epochs=100,
    batch_size=32,
    validation_data=(X_test, Y_test),
    callbacks=[early_stop]
)
# Out:
# Epoch 1/100
# 646/646 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7263 - loss: 0.5795 - val_accuracy: 0.7455 - val_loss: 0.5484
# Epoch 2/100
# 646/646 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7477 - loss: 0.5463 - val_accuracy: 0.7538 - val_loss: 0.5389
# Epoch 3/100
# 646/646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7521 - loss: 0.5406 - val_accuracy: 0.7536 - val_loss: 0.5346
# Epoch 4/100
# 646/646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7543 - loss: 0.5359 - val_accuracy: 0.7528 - val_loss: 0.5314
# Epoch 5/100
# 646/646 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7577 - loss: 0.5320 - val_accuracy: 0.7613 - val_loss: 0.5281
# Epoch 6/100
# 646/646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7586 - loss: 0.5311 - val_accuracy: 0.7576 - val_loss: 0.5267
# Epoch 7/100
# 646/646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7585 - loss: 0.5301 - val_accuracy: 0.7617 - val_loss: 0.5265
# Epoch 8/100
# 646/646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7598 - loss: 0.5272 - val_accuracy: 0.7654 - val_loss: 0.5238
# Epoch 9/100
# 646/646 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7606 - loss: 0.5258 - val_accuracy: 0.7617 - val_loss: 0.5232
# Epoch 10/100
# 646/646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7617 - loss: 0.5256 - val_accuracy: 0.7658 - val_loss: 0.5230
# Epoch 11/100
# 646/646 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7611 - loss: 0.5254 - val_accuracy: 0.7640 - val_loss: 0.5223
# Epoch 12/100
# 646/646 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7614 - loss: 0.5237 - val_accuracy: 0.7652 - val_loss: 0.5212
# Epoch 13/100
# 646/646 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7631 - loss: 0.5236 - val_accuracy: 0.7640 - val_loss: 0.5211
# Epoch 14/100
# 646/646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7633 - loss: 0.5234 - val_accuracy: 0.7623 - val_loss: 0.5216
# Epoch 15/100
# 646/646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7624 - loss: 0.5234 - val_accuracy: 0.7673 - val_loss: 0.5207
# Epoch 16/100
# 646/646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7639 - loss: 0.5213 - val_accuracy: 0.7671 - val_loss: 0.5205
# Epoch 17/100
# 646/646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7639 - loss: 0.5217 - val_accuracy: 0.7638 - val_loss: 0.5200
# Epoch 18/100
# 646/646 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7643 - loss: 0.5208 - val_accuracy: 0.7638 - val_loss: 0.5205
# Epoch 19/100
# 646/646 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.
100
# 646/646 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7725 - loss: 0.4994 - val_accuracy: 0.7755 - val_loss: 0.4949
# Epoch 83/100
# 646/646 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7729 - loss: 0.4988 - val_accuracy: 0.7753 - val_loss: 0.4943
# Epoch 84/100
# 646/646 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7738 - loss: 0.4972 - val_accuracy: 0.7747 - val_loss: 0.4944

# %%
# !pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\rkbhuyan\appdata\local\programs\python\python313\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\rkbhuyan\appdata\local\programs\python\python313\lib\site-packages (from seaborn) (2.4.4)
# Requirement already satisfied: pandas>=1.2 in c:\users\rkbhuyan\appdata\local\programs\python\python313\lib\site-packages (from seaborn) (3.0.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\rkbhuyan\appdata\local\programs\python\python313\lib\site-packages (from seaborn) (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\rkbhuyan\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\rkbhuyan\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\rkbhuyan\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\rkbhuyan\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\rkbhuyan\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (26.0)
# Requirement already satisfied: pillow>=8 in c:\users\rkbhuyan\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\rkbhuyan\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\rkbhuyan\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\rkbhuyan\appdata\local\programs\python\python313\lib\site-packages (from pandas>=1.2->seaborn) (2026.1)
# Requirement already satisfied: six>=1.5 in c:\users\rkbhuyan\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Plotting the model accuracy 
import seaborn as sns
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show(block=True)

# %%
loss, accuracy = model.evaluate(X_test, Y_test)
print(f"\nModel Accuracy: {accuracy:.4f}")
# Out:
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7751 - loss: 0.4941
#
# Model Accuracy: 0.7751

# %%
X_train
# Out:
# array([[ 0.46243881,  1.82499137, -0.64813819],
#        [ 0.44941763, -0.28422264, -0.64813819],
#        [ 0.62542808, -0.98729398, -0.64813819],
#        ...,
#        [ 0.2967555 , -1.69036532, -0.13700864],
#        [-0.01620186,  0.06731302, -0.13700864],
#        [ 0.24826283, -1.33882965,  0.37412091]], shape=(20664, 3))

# %%
X_test
# Out:
# array([[ 0.24152773,  1.12192003,  0.37412091],
#        [ 0.21862841, -1.33882965, -0.13700864],
#        [ 0.07764045, -0.63575831, -0.13700864],
#        ...,
#        [ 0.21862841, -1.69036532, -0.13700864],
#        [ 0.21997543, -1.33882965, -0.13700864],
#        [-0.20747853,  1.82499137,  0.11855613]], shape=(5166, 3))

# %%
Y_train
# Out:
# array([0, 1, 1, ..., 1, 1, 0], shape=(20664,))

# %%
Y_test
# Out:
# array([1, 0, 1, ..., 1, 1, 1], shape=(5166,))

# %%
Y_pred = model.predict(X_test)  # predicting the truck breakdown using our ANN model
Y_pred
# Out:
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# array([[0.85596544],
#        [0.76878905],
#        [0.84019357],
#        ...,
#        [0.7694322 ],
#        [0.76857376],
#        [0.8843485 ]], shape=(5166, 1), dtype=float32)

# %%
Y_pred_binary = (Y_pred > 0.5).astype(int)
Y_pred_binary
# Out:
# array([[1],
#        [1],
#        [1],
#        ...,
#        [1],
#        [1],
#        [1]], shape=(5166, 1))

# %%
len(Y_pred_binary)
# Out:
# 5166

# %%
indexes_of_0s = np.where(Y_pred_binary == 0)[0]
indexes_of_1s = np.where(Y_pred_binary == 1)[0]

# %%
indexes_of_0s
# Out:
# array([  12,   13,   20,   24,   32,   37,   49,   50,   63,   88,  106,
#         107,  108,  113,  114,  125,  127,  133,  149,  151,  155,  164,
#         180,  191,  199,  202,  211,  214,  234,  242,  249,  252,  255,
#         256,  258,  259,  263,  269,  276,  282,  283,  292,  293,  294,
#         305,  309,  321,  324,  326,  330,  359,  378,  384,  388,  398,
#         400,  408,  426,  428,  429,  440,  458,  465,  472,  483,  488,
#         492,  498,  505,  510,  512,  517,  535,  539,  548,  563,  598,
#         601,  610,  612,  615,  618,  624,  625,  626,  633,  654,  669,
#         671,  678,  685,  698,  699,  705,  706,  711,  715,  717,  731,
#         742,  743,  750,  755,  756,  760,  773,  774,  779,  784,  786,
#         793,  794,  801,  806,  848,  849,  863,  887,  888,  889,  904,
#         905,  922,  929,  931,  932,  947,  950,  961,  963,  981,  989,
#        1010, 1022, 1026, 1030, 1036, 1037, 1042, 1048, 1049, 1067, 1074,
#        1077, 1081, 1110, 1119, 1121, 1126, 1155, 1170, 1173, 1181, 1185,
#        3834, 3835, 3857, 3865, 3875, 3880, 3881, 3883, 3885, 3890, 3892,
#        3908, 3917, 3920, 3930, 3938, 3940, 3942, 3959, 3961, 3969, 3973,
#        3984, 3990, 3997, 4007, 4009, 4011, 4015, 4017, 4018, 4019, 4025,
#        4031, 4036, 4043, 4047, 4060, 4068, 4071, 4076, 4085, 4086, 4094,
#        4105, 4122, 4127, 4146, 4153, 4155, 4158, 4170, 4174, 4175, 4177,
#        4178, 4186, 4189, 4191, 4193, 4200, 4204, 4218, 4222, 4227, 4228,
#        4247, 4267, 4270, 4280, 4289, 4290, 4297, 4298, 4316, 4322, 4329,
#        4348, 4357, 4361, 4365, 4367, 4373, 4380, 4394, 4396, 4398, 4412,
#        4414, 4419, 4420, 4429, 4432, 4440, 4450, 4451, 4467, 4471, 4481,
#        4482, 4486, 4497, 4502, 4505, 4528, 4535, 4540, 4550, 4551, 4559,
#        4569, 4571, 4599, 4602, 4604, 4610, 4612, 4633, 4636, 4645, 4654,
#        4656, 4663, 4669, 4680, 4685, 4686, 4688, 4694, 4707, 4709, 4713,
#        4718, 4720, 4725, 4731, 4734, 4736, 4748, 4754, 4758, 4760, 4763,
#        4764, 4765, 4772, 4780, 4782, 4788, 4798, 4802, 4805, 4806, 4809,
#        4810, 4811, 4813, 4815, 4833, 4836, 4837, 4841, 4846, 4874, 4876,
#        4909, 4914, 4917, 4934, 4942, 4946, 4947, 4955, 4972, 4974, 4982,
#        4994, 5005, 5012, 5013, 5019, 5024, 5036, 5037, 5040, 5045, 5051,
#        5053, 5059, 5060, 5063, 5078, 5081, 5086, 5088, 5092, 5094, 5097,
#        5101, 5113, 5115, 5119, 5120, 5121, 5124, 5126, 5131, 5135, 5143,
#        5148, 5150, 5154, 5155])

# %%
indexes_of_1s
# Out:
# array([   0,    1,    2, ..., 5163, 5164, 5165], shape=(4436,))

# %%
Y_pred_binary[2637]
# Out:
# array([0])

# %%
df_Y_pred = pd.DataFrame(Y_pred_binary, columns=['description'])
df_Y_pred
# Out:
#       description
# 0               1
# 1               1
# 2               1
# 3               1
# 4               1
# ...           ...
# 5161            1
# 5162            1
# 5163            1
# 5164            1
# 5165            1
#
# [5166 rows x 1 columns]

# %%
X_test_original = scaler.inverse_transform(X_test)  # Decoding the test features into its original values
X_test_original
# Out:
# array([[100.51,  32.4 ,   0.  ],
#        [100.  ,   7.2 ,  -4.  ],
#        [ 96.86,  14.4 ,  -4.  ],
#        ...,
#        [100.  ,   3.6 ,  -4.  ],
#        [100.03,   7.2 ,  -4.  ],
#        [ 90.51,  39.6 ,  -2.  ]], shape=(5166, 3))

# %%
df_feature_original = pd.DataFrame(X_test_original, columns=['tonnage_percentage', 'speed', 'gradient'])
df_feature_original
# Out:
#       tonnage_percentage  speed  gradient
# 0                 100.51   32.4       0.0
# 1                 100.00    7.2      -4.0
# 2                  96.86   14.4      -4.0
# 3                 102.49   21.6      -4.0
# 4                  94.14   25.2       0.0
# ...                  ...    ...       ...
# 5161              100.00   21.6       0.0
# 5162              103.06   10.8       0.0
# 5163              100.00    3.6      -4.0
# 5164              100.03    7.2      -4.0
# 5165               90.51   39.6      -2.0
#
# [5166 rows x 3 columns]

# %%
df_test = pd.concat([df_feature_original, df_Y_pred], axis=1)
df_test
# Out:
#       tonnage_percentage  speed  gradient  description
# 0                 100.51   32.4       0.0            1
# 1                 100.00    7.2      -4.0            1
# 2                  96.86   14.4      -4.0            1
# 3                 102.49   21.6      -4.0            1
# 4                  94.14   25.2       0.0            1
# ...                  ...    ...       ...          ...
# 5161              100.00   21.6       0.0            1
# 5162              103.06   10.8       0.0            1
# 5163              100.00    3.6      -4.0            1
# 5164              100.03    7.2      -4.0            1
# 5165               90.51   39.6      -2.0            1
#
# [5166 rows x 4 columns]

# %%
plt.hist(df_test['description'], bins=20)
plt.xlabel('Predicted Probability')
plt.ylabel('Frequency')
plt.title('Distribution of Predicted Probabilities')
plt.show(block=True)

# %%
mapping_dict = {0: 'Cannot cause tire breakdown', 1: 'Could cause tire breakdown'}

# %%
df_test['description'] = df_test['description'].map(mapping_dict)  # Classifying our description values into meanigful mappings
df_test
# Out:
#       tonnage_percentage  speed  gradient                 description
# 0                 100.51   32.4       0.0  Could cause tire breakdown
# 1                 100.00    7.2      -4.0  Could cause tire breakdown
# 2                  96.86   14.4      -4.0  Could cause tire breakdown
# 3                 102.49   21.6      -4.0  Could cause tire breakdown
# 4                  94.14   25.2       0.0  Could cause tire breakdown
# ...                  ...    ...       ...                         ...
# 5161              100.00   21.6       0.0  Could cause tire breakdown
# 5162              103.06   10.8       0.0  Could cause tire breakdown
# 5163              100.00    3.6      -4.0  Could cause tire breakdown
# 5164              100.03    7.2      -4.0  Could cause tire breakdown
# 5165               90.51   39.6      -2.0  Could cause tire breakdown
#
# [5166 rows x 4 columns]

# %% [markdown]
# MODEL PERFORMANCE METRICS

# %%
from sklearn.metrics import confusion_matrix, classification_report, precision_score, recall_score, f1_score

# %%
Y_pred_binary
# Out:
# array([[1],
#        [1],
#        [1],
#        ...,
#        [1],
#        [1],
#        [1]], shape=(5166, 1))

# %%
Y_test
# Out:
# array([1, 0, 1, ..., 1, 1, 1], shape=(5166,))

# %%
# CONFUSION MATRIX
import numpy as np

cm = confusion_matrix(Y_test, Y_pred_binary)

cm_percent = cm / cm.sum(axis=1, keepdims=True)

plt.figure(figsize=(6,5))
sns.heatmap(cm_percent, 
            annot=True, 
            fmt=".2f", 
            cmap='Blues',
            xticklabels=["No Risk", "Risk"],
            yticklabels=["No Risk", "Risk"])

plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

# %%
precision = precision_score(Y_test, Y_pred_binary)
recall = recall_score(Y_test, Y_pred_binary)
f1 = f1_score(Y_test, Y_pred_binary)

print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"F1 Score: {f1:.2f}")
# Out:
# Precision: 0.76
# Recall: 0.98
# F1 Score: 0.85

# %%
print(classification_report(Y_test, Y_pred_binary))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.38      0.53      1732
#            1       0.76      0.98      0.85      3434
#
#     accuracy                           0.78      5166
#    macro avg       0.82      0.68      0.69      5166
# weighted avg       0.80      0.78      0.74      5166

# %% [markdown]
# SAVING OUR TRAINED MODEL

# %%
import joblib

joblib.dump(model, "surface_model.pkl")
joblib.dump(scaler, "scaler_surface.pkl")
# Out:
# ['scaler_surface.pkl']
