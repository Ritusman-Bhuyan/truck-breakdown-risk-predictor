# %% [markdown]
# INSTALLING TENSORFLOW

# %%
# !pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\rkbhuyan\appdata\local\programs\python\python313\lib\site-packages (2.21.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\rkbhuyan\appdata\local\programs\python\python313\lib\site-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\rkbhuyan\appdata\local\programs\python\python313\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=25.9.23 in c:\users\rkbhuyan\appdata\local\programs\python\python313\lib\site-packages (from tensorflow) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\rkbhuyan\appdata\local\programs\python\python313\lib\site-packages (from tensorflow) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in c:\users\rkbhuyan\appdata\local\programs\python\python313\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\rkbhuyan\appdata\local\programs\python\python313\lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in c:\users\rkbhuyan\appdata\local\programs\python\python313\lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\users\rkbhuyan\appdata\local\programs\python\python313\lib\site-packages (from tensorflow) (26.0)
# Requirement already satisfied: protobuf<8.0.0,>=6.31.1 in c:\users\rkbhuyan\appdata\local\programs\python\python313\lib\site-packages (from tensorflow) (7.34.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\rkbhuyan\appdata\local\programs\python\python313\lib\site-packages (from tensorflow) (2.33.1)
# Requirement already satisfied: setuptools in c:\users\rkbhuyan\appdata\local\programs\python\python313\lib\site-packages (from tensorflow) (81.0.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\rkbhuyan\appdata\local\programs\python\python313\lib\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\rkbhuyan\appdata\local\programs\python\python313\lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in c:\users\rkbhuyan\appdata\local\programs\python\python313\lib\site-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\rkbhuyan\appdata\local\programs\python\python313\lib\site-packages (from tensorflow) (2.1.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\rkbhuyan\appdata\local\programs\python\python313\lib\site-packages (from tensorflow) (1.80.0)
# Requirement already satisfied: keras>=3.12.0 in c:\users\rkbhuyan\appdata\local\programs\python\python313\lib\site-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\rkbhuyan\appdata\local\programs\python\python313\lib\site-packages (from tensorflow) (2.4.4)
# Requirement already satisfied: h5py<3.15.0,>=3.11.0 in c:\users\rkbhuyan\appdata\local\programs\python\python313\lib\site-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in c:\users\rkbhuyan\appdata\local\programs\python\python313\lib\site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\rkbhuyan\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\rkbhuyan\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.11)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\rkbhuyan\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.6.3)
# Requirement already satisfied: certifi>=2023.5.7 in c:\users\rkbhuyan\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2026.2.25)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\rkbhuyan\appdata\local\programs\python\python313\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.46.3)
# Requirement already satisfied: rich in c:\users\rkbhuyan\appdata\local\programs\python\python313\lib\site-packages (from keras>=3.12.0->tensorflow) (15.0.0)
# Requirement already satisfied: namex in c:\users\rkbhuyan\appdata\local\programs\python\python313\lib\site-packages (from keras>=3.12.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in c:\users\rkbhuyan\appdata\local\programs\python\python313\lib\site-packages (from keras>=3.12.0->tensorflow) (0.19.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\rkbhuyan\appdata\local\programs\python\python313\lib\site-packages (from rich->keras>=3.12.0->tensorflow) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\rkbhuyan\appdata\local\programs\python\python313\lib\site-packages (from rich->keras>=3.12.0->tensorflow) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\rkbhuyan\appdata\local\programs\python\python313\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.12.0->tensorflow) (0.1.2)
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np 
import tensorflow as tf

# %% [markdown]
# PREPARING THE DATASET

# %%
df1 = pd.read_csv('data-with-concern.csv')  # importing the dataset for the tire breakdown reasons
df1
# Out:
#                description material_name  tonnage_percentage  speed  \
# 0           ARO/RIN/BIRLOS         INPIT                98.4   18.0
# 1           ARO/RIN/BIRLOS         INPIT                98.4   21.6
# 2           ARO/RIN/BIRLOS         INPIT                98.4   21.6
# 3           ARO/RIN/BIRLOS         INPIT                98.4   25.2
# 4           ARO/RIN/BIRLOS         INPIT                98.4   25.2
# ...                    ...           ...                 ...    ...
# 29142  ROTACION DE LLANTAS      TEPETATE                 NaN   39.6
# 29143  ROTACION DE LLANTAS      TEPETATE                 NaN   43.2
# 29144  ROTACION DE LLANTAS      TEPETATE                 NaN   43.2
# 29145  ROTACION DE LLANTAS      TEPETATE                 NaN   43.2
# 29146  ROTACION DE LLANTAS      TEPETATE                 NaN   46.8
#
#       road_category  gradient
# 0              Lift         0
# 1              Lift         2
# 2              Lift         7
# 3              Lift         0
# 4              Lift         2
# ...             ...       ...
# 29142       Surface        12
# 29143          Lift         8
# 29144       Surface        -1
# 29145       Surface        12
# 29146       Surface        -1
#
# [29147 rows x 6 columns]

# %%
df1 = df1[['description','tonnage_percentage','speed','road_category','gradient']]  # Extracting the neccessary columns
df1
# Out:
#                description  tonnage_percentage  speed road_category  gradient
# 0           ARO/RIN/BIRLOS                98.4   18.0          Lift         0
# 1           ARO/RIN/BIRLOS                98.4   21.6          Lift         2
# 2           ARO/RIN/BIRLOS                98.4   21.6          Lift         7
# 3           ARO/RIN/BIRLOS                98.4   25.2          Lift         0
# 4           ARO/RIN/BIRLOS                98.4   25.2          Lift         2
# ...                    ...                 ...    ...           ...       ...
# 29142  ROTACION DE LLANTAS                 NaN   39.6       Surface        12
# 29143  ROTACION DE LLANTAS                 NaN   43.2          Lift         8
# 29144  ROTACION DE LLANTAS                 NaN   43.2       Surface        -1
# 29145  ROTACION DE LLANTAS                 NaN   43.2       Surface        12
# 29146  ROTACION DE LLANTAS                 NaN   46.8       Surface        -1
#
# [29147 rows x 5 columns]

# %%
df2 = pd.read_csv('data-without-concern.csv')  # Importing the dataset for no tire breakdown reasons
df2
# Out:
#        description material_name  tonnage_percentage  speed road_category  \
# 0              A/C         INPIT              100.00    3.6          Dump
# 1              A/C         INPIT              100.00   18.0          Dump
# 2              A/C    LIXIVIABLE               94.89   10.8          Lift
# 3              A/C    LIXIVIABLE               94.89   14.4          Lift
# 4              A/C    LIXIVIABLE               94.89   14.4          Lift
# ...            ...           ...                 ...    ...           ...
# 29681  TRANSMISION      TEPETATE                 NaN   25.2          Lift
# 29682  TRANSMISION      TEPETATE                 NaN   28.8          Lift
# 29683  TRANSMISION      TEPETATE                 NaN   32.4          Lift
# 29684  TRANSMISION      TEPETATE                 NaN   36.0          Lift
# 29685  TRANSMISION      TEPETATE                 NaN   46.8          Lift
#
#        gradient
# 0            -4
# 1            -4
# 2             5
# 3             4
# 4             5
# ...         ...
# 29681         5
# 29682        -6
# 29683        -6
# 29684        -6
# 29685        -6
#
# [29686 rows x 6 columns]

# %%
df2 = df2[['description','tonnage_percentage','speed','road_category','gradient']]  # Extracting the neccessary columns
df2
# Out:
#        description  tonnage_percentage  speed road_category  gradient
# 0              A/C              100.00    3.6          Dump        -4
# 1              A/C              100.00   18.0          Dump        -4
# 2              A/C               94.89   10.8          Lift         5
# 3              A/C               94.89   14.4          Lift         4
# 4              A/C               94.89   14.4          Lift         5
# ...            ...                 ...    ...           ...       ...
# 29681  TRANSMISION                 NaN   25.2          Lift         5
# 29682  TRANSMISION                 NaN   28.8          Lift        -6
# 29683  TRANSMISION                 NaN   32.4          Lift        -6
# 29684  TRANSMISION                 NaN   36.0          Lift        -6
# 29685  TRANSMISION                 NaN   46.8          Lift        -6
#
# [29686 rows x 5 columns]

# %%
df1['description'] = 'Yes'  # Replacing the tire breakdown reasons description by a single boolean variable (which will be encoded later on while training our model)
df1
# Out:
#       description  tonnage_percentage  speed road_category  gradient
# 0             Yes                98.4   18.0          Lift         0
# 1             Yes                98.4   21.6          Lift         2
# 2             Yes                98.4   21.6          Lift         7
# 3             Yes                98.4   25.2          Lift         0
# 4             Yes                98.4   25.2          Lift         2
# ...           ...                 ...    ...           ...       ...
# 29142         Yes                 NaN   39.6       Surface        12
# 29143         Yes                 NaN   43.2          Lift         8
# 29144         Yes                 NaN   43.2       Surface        -1
# 29145         Yes                 NaN   43.2       Surface        12
# 29146         Yes                 NaN   46.8       Surface        -1
#
# [29147 rows x 5 columns]

# %%
df2['description'] = 'No'  # Replacing the non tire breakdown reasons description by a single boolean variable (which will be encoded later on while training our model)
df2
# Out:
#       description  tonnage_percentage  speed road_category  gradient
# 0              No              100.00    3.6          Dump        -4
# 1              No              100.00   18.0          Dump        -4
# 2              No               94.89   10.8          Lift         5
# 3              No               94.89   14.4          Lift         4
# 4              No               94.89   14.4          Lift         5
# ...           ...                 ...    ...           ...       ...
# 29681          No                 NaN   25.2          Lift         5
# 29682          No                 NaN   28.8          Lift        -6
# 29683          No                 NaN   32.4          Lift        -6
# 29684          No                 NaN   36.0          Lift        -6
# 29685          No                 NaN   46.8          Lift        -6
#
# [29686 rows x 5 columns]

# %%
df = pd.concat([df1, df2], ignore_index=True)  # Concating all the tire breakdown and non tire breakdown reasons to prepare final dataset
df
# Out:
#       description  tonnage_percentage  speed road_category  gradient
# 0             Yes                98.4   18.0          Lift         0
# 1             Yes                98.4   21.6          Lift         2
# 2             Yes                98.4   21.6          Lift         7
# 3             Yes                98.4   25.2          Lift         0
# 4             Yes                98.4   25.2          Lift         2
# ...           ...                 ...    ...           ...       ...
# 58828          No                 NaN   25.2          Lift         5
# 58829          No                 NaN   28.8          Lift        -6
# 58830          No                 NaN   32.4          Lift        -6
# 58831          No                 NaN   36.0          Lift        -6
# 58832          No                 NaN   46.8          Lift        -6
#
# [58833 rows x 5 columns]

# %%
df = df[(df['road_category'] == 'Dump')]  # Filtering our dataset on Surface tye road categories

# %% [markdown]
# FINAL DATASET

# %%
df
# Out:
#       description  tonnage_percentage  speed road_category  gradient
# 258           Yes                98.4   10.8          Dump         0
# 259           Yes                98.4   18.0          Dump         0
# 260           Yes                98.4   21.6          Dump         0
# 261           Yes                98.4   25.2          Dump         0
# 262           Yes                98.4   32.4          Dump         0
# ...           ...                 ...    ...           ...       ...
# 58542          No               100.0   21.6          Dump         0
# 58726          No               100.0   18.0          Dump         0
# 58729          No               100.0   21.6          Dump         0
# 58822          No                 NaN   18.0          Dump         0
# 58825          No                 NaN   21.6          Dump         0
#
# [13538 rows x 5 columns]

# %%
df = df.fillna(0)  # Replacing all Null values by 0
df
# Out:
#       description  tonnage_percentage  speed road_category  gradient
# 258           Yes                98.4   10.8          Dump         0
# 259           Yes                98.4   18.0          Dump         0
# 260           Yes                98.4   21.6          Dump         0
# 261           Yes                98.4   25.2          Dump         0
# 262           Yes                98.4   32.4          Dump         0
# ...           ...                 ...    ...           ...       ...
# 58542          No               100.0   21.6          Dump         0
# 58726          No               100.0   18.0          Dump         0
# 58729          No               100.0   21.6          Dump         0
# 58822          No                 0.0   18.0          Dump         0
# 58825          No                 0.0   21.6          Dump         0
#
# [13538 rows x 5 columns]

# %% [markdown]
# DIVIDING THE FEATURE AND TARGET DATA

# %%
feature = df.drop(['description','road_category'], axis=1)  # Dividing feature and target columns
feature
# Out:
#        tonnage_percentage  speed  gradient
# 258                  98.4   10.8         0
# 259                  98.4   18.0         0
# 260                  98.4   21.6         0
# 261                  98.4   25.2         0
# 262                  98.4   32.4         0
# ...                   ...    ...       ...
# 58542               100.0   21.6         0
# 58726               100.0   18.0         0
# 58729               100.0   21.6         0
# 58822                 0.0   18.0         0
# 58825                 0.0   21.6         0
#
# [13538 rows x 3 columns]

# %%
X = feature.values  # Converting our features into a numpy array
X
# Out:
# array([[ 98.4,  10.8,   0. ],
#        [ 98.4,  18. ,   0. ],
#        [ 98.4,  21.6,   0. ],
#        ...,
#        [100. ,  21.6,   0. ],
#        [  0. ,  18. ,   0. ],
#        [  0. ,  21.6,   0. ]], shape=(13538, 3))

# %% [markdown]
# SCALING THE FEATURE VALUES

# %%
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\rkbhuyan\appdata\local\programs\python\python313\lib\site-packages (1.8.0)
# Requirement already satisfied: numpy>=1.24.1 in c:\users\rkbhuyan\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn) (2.4.4)
# Requirement already satisfied: scipy>=1.10.0 in c:\users\rkbhuyan\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn) (1.17.1)
# Requirement already satisfied: joblib>=1.3.0 in c:\users\rkbhuyan\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\rkbhuyan\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn) (3.6.0)
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import sklearn

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
X = scaler.fit_transform(X)  # Scaling our feature values
X
# Out:
# array([[ 0.13452831, -0.87492235,  0.59050155],
#        [ 0.13452831, -0.15690951,  0.59050155],
#        [ 0.13452831,  0.20209691,  0.59050155],
#        ...,
#        [ 0.20975574,  0.20209691,  0.59050155],
#        [-4.49195844, -0.15690951,  0.59050155],
#        [-4.49195844,  0.20209691,  0.59050155]], shape=(13538, 3))

# %%
df
# Out:
#       description  tonnage_percentage  speed road_category  gradient
# 258           Yes                98.4   10.8          Dump         0
# 259           Yes                98.4   18.0          Dump         0
# 260           Yes                98.4   21.6          Dump         0
# 261           Yes                98.4   25.2          Dump         0
# 262           Yes                98.4   32.4          Dump         0
# ...           ...                 ...    ...           ...       ...
# 58542          No               100.0   21.6          Dump         0
# 58726          No               100.0   18.0          Dump         0
# 58729          No               100.0   21.6          Dump         0
# 58822          No                 0.0   18.0          Dump         0
# 58825          No                 0.0   21.6          Dump         0
#
# [13538 rows x 5 columns]

# %% [markdown]
# ENCODING OUR FEATURE VALUES INTO YES/NO

# %%
from sklearn.preprocessing import LabelEncoder, StandardScaler

# %%
label_encoder = LabelEncoder()

# %%
Y = label_encoder.fit_transform(df['description'])  # Encoding our boolean variable: YES-1, NO-0
Y
# Out:
# array([1, 1, 1, ..., 0, 0, 0], shape=(13538,))

# %% [markdown]
# SPLITTING OUR MODEL FOR TRAINING AND TESTING

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42, stratify=Y)  # Splitting our dataset into 80% testing and 20% testing datasets

# %% [markdown]
# BUILDING OUR ANN MODEL FOR RISK PREDICTION

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Dense, Dropout, Input
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
model = tf.keras.models.Sequential()  # Creating a sequential neural network model

# %%
model.add(tf.keras.Input(shape = (3,)))   # input layer

# %%
model.add(tf.keras.layers.Dense(units = 32, activation = 'relu'))  # 1st hidden layer
model.add(Dropout(0.1))

# %%
model.add(tf.keras.layers.Dense(units = 12, activation = 'relu'))  # 2nd hidden layer

# %%
model.add(tf.keras.layers.Dense(units = 1, activation = 'sigmoid'))  # output layer

# %%
model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics=['accuracy'])  # Compiling our model
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %%
early_stop = EarlyStopping(
    monitor='val_loss',
    patience=5,   # stop if no improvement for 5 epochs
    restore_best_weights=True
)

# %%
history = model.fit(
    X_train, Y_train,
    epochs=100,
    batch_size=32,
    validation_data=(X_test, Y_test),
    callbacks=[early_stop]
)
# Out:
# Epoch 1/100
# 339/339 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.6525 - loss: 0.6527 - val_accuracy: 0.6617 - val_loss: 0.6352
# Epoch 2/100
# 339/339 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6633 - loss: 0.6344 - val_accuracy: 0.6706 - val_loss: 0.6284
# Epoch 3/100
# 339/339 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6696 - loss: 0.6280 - val_accuracy: 0.6577 - val_loss: 0.6256
# Epoch 4/100
# 339/339 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6687 - loss: 0.6255 - val_accuracy: 0.6647 - val_loss: 0.6223
# Epoch 5/100
# 339/339 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6710 - loss: 0.6223 - val_accuracy: 0.6658 - val_loss: 0.6196
# Epoch 6/100
# 339/339 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6701 - loss: 0.6212 - val_accuracy: 0.6739 - val_loss: 0.6173
# Epoch 7/100
# 339/339 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6704 - loss: 0.6207 - val_accuracy: 0.6728 - val_loss: 0.6153
# Epoch 8/100
# 339/339 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6688 - loss: 0.6187 - val_accuracy: 0.6780 - val_loss: 0.6138
# Epoch 9/100
# 339/339 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6715 - loss: 0.6179 - val_accuracy: 0.6758 - val_loss: 0.6116
# Epoch 10/100
# 339/339 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6716 - loss: 0.6151 - val_accuracy: 0.6784 - val_loss: 0.6101
# Epoch 11/100
# 339/339 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6746 - loss: 0.6143 - val_accuracy: 0.6865 - val_loss: 0.6080
# Epoch 12/100
# 339/339 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6766 - loss: 0.6129 - val_accuracy: 0.6894 - val_loss: 0.6060
# Epoch 13/100
# 339/339 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6756 - loss: 0.6122 - val_accuracy: 0.6795 - val_loss: 0.6055
# Epoch 14/100
# 339/339 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6754 - loss: 0.6130 - val_accuracy: 0.6913 - val_loss: 0.6047
# Epoch 15/100
# 339/339 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6797 - loss: 0.6098 - val_accuracy: 0.6909 - val_loss: 0.6024
# Epoch 16/100
# 339/339 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6849 - loss: 0.6084 - val_accuracy: 0.6876 - val_loss: 0.6005
# Epoch 17/100
# 339/339 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6874 - loss: 0.6072 - val_accuracy: 0.7027 - val_loss: 0.5985
# Epoch 18/100
# 339/339 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6940 - loss: 0.6056 - val_accuracy: 0.7005 - val_loss: 0.5971
# Epoch 19/100
# 339/339 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6932 - loss: 0.6057 - val_accuracy: 0.7053 - val_loss: 0.5953
# Epoch 20/100
# 339/339 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6984 - loss: 0.6026 - val_accuracy: 0.7049 - val_loss: 0.5946
# Epoch 21/100
# 339/339 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6977 - loss: 0.6033 - val_accuracy: 0.7094 - val_loss: 0.5918
# Epoch 22/100
# 339/339 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7008 - loss: 0.6024 - val_accuracy: 0.7175 - val_loss: 0.5897
# Epoch 23/100
# 339/339 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.6984 - loss: 0.6013 - val_accuracy: 0.7090 - val_loss: 0.5887
# Epoch 24/100
# 339/339 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6992 - loss: 0.5987 - val_accuracy: 0.7116 - val_loss: 0.5876
# Epoch 25/100
# 339/339 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7011 - loss: 0.5978 - val_accuracy: 0.7027 - val_loss: 0.5868
# Epoch 26/100
# 339/339 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7015 - loss: 0.5976 - val_accuracy: 0.7094 - val_loss: 0.5837
# Epoch 27/100
# 339/339 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7019 - loss: 0.5957 - val_accuracy: 0.7075 - val_loss: 0.5817
# Epoch 28/100
# 339/339 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6994 - loss: 0.5968 - val_accuracy: 0.7105 - val_loss: 0.5801
# Epoch 29/100
# 339/339 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7012 - loss: 0.5943 - val_accuracy: 0.7131 - val_loss: 0.5781
# Epoch 30/100
# 339/339 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7030 - loss: 0.5929 - val_accuracy: 0.7079 - val_loss: 0.5787
# Epoch 31/100
# 339/339 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7024 - loss: 0.5923 - val_accuracy: 0.7168 - val_loss: 0.5756
# Epoch 32/100
# 339/339 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7006 - loss: 0.5892 - val_accuracy: 0.7142 - val_loss: 0.5779
# Epoch 33/100
# 339/339 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7003 - loss: 0.5907 - val_accuracy: 0.7105 - val_loss: 0.5749
# Epoch 34/100
# 339/339 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7018 - loss: 0.5906 - val_accuracy: 0.7064 - val_loss: 0.5726
# Epoch 35/100
# 339/339 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6997 - loss: 0.5883 - val_accuracy: 0.7142 - val_loss: 0.5747
# Epoch 36/100
# 339/339 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7029 - loss: 0.5866 - val_accuracy: 0.7123 - val_loss: 0.5717
# Epoch 37/100
# 339/339 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7031 - loss: 0.5868 - val_accuracy: 0.7105 - val_loss: 0.5698
# Epoch 38/100
# 339/339 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7047 - loss: 0.5844 - val_accuracy: 0.7072 - val_loss: 0.5680
# Epoch 39/100
# 339/339 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7013 - loss: 0.5860 - val_accuracy: 0.7127 - val_loss: 0.5687
# Epoch 40/100
# 339/339 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7051 - loss: 0.5850 - val_accuracy: 0.7116 - val_loss: 0.5699
# Epoch 41/100
# 339/339 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7030 - loss: 0.5850 - val_accuracy: 0.7171 - val_loss: 0.5695
# Epoch 42/100
# 339/339 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7036 - loss: 0.5836 - val_accuracy: 0.7127 - val_loss: 0.5653
# Epoch 43/100
# 339/339 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7038 - loss: 0.5823 - val_accuracy: 0.7138 - val_loss: 0.5663
# Epoch 44/100
# 339/339 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7040 - loss: 0.5843 - val_accuracy: 0.7149 - val_loss: 0.5660
# Epoch 45/100
# 339/339 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7046 - loss: 0.5813 - val_accuracy: 0.7153 - val_loss: 0.5657
# Epoch 46/100
# 339/339 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7042 - loss: 0.5820 - val_accuracy: 0.7116 - val_loss: 0.5678
# Epoch 47/100
# 339/339 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7058 - loss: 0.5806 - val_accuracy: 0.7086 - val_loss: 0.5643
# Epoch 48/100
# 339/339 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7066 - loss: 0.5801 - val_accuracy: 0.7109 - val_loss: 0.5636
# Epoch 49/100
# 339/339 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7022 - loss: 0.5818 - val_accuracy: 0.7208 - val_loss: 0.5610
# Epoch 50/100
# 339/339 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7039 - loss: 0.5797 - val_accuracy: 0.7101 - val_loss: 0.5652
# Epoch 51/100
# 339/339 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7036 - loss: 0.5808 - val_accuracy: 0.7197 - val_loss: 0.5613
# Epoch 52/100
# 339/339 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7031 - loss: 0.5808 - val_accuracy: 0.7123 - val_loss: 0.5607
# Epoch 53/100
# 339/339 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7054 - loss: 0.5786 - val_accuracy: 0.7097 - val_loss: 0.5605
# Epoch 54/100
# 339/339 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7036 - loss: 0.5803 - val_accuracy: 0.7197 - val_loss: 0.5607
# Epoch 55/100
# 339/339 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7051 - loss: 0.5777 - val_accuracy: 0.7134 - val_loss: 0.5592
# Epoch 56/100
# 339/339 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7047 - loss: 0.5779 - val_accuracy: 0.7219 - val_loss: 0.5602
# Epoch 57/100
# 339/339 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7059 - loss: 0.5762 - val_accuracy: 0.7138 - val_loss: 0.5596
# Epoch 58/100
# 339/339 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7052 - loss: 0.5757 - val_accuracy: 0.7105 - val_loss: 0.5576
# Epoch 59/100
# 339/339 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7053 - loss: 0.5776 - val_accuracy: 0.7127 - val_loss: 0.5568
# Epoch 60/100
# 339/339 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7016 - loss: 0.5771 - val_accuracy: 0.7157 - val_loss: 0.5585
# Epoch 61/100
# 339/339 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7071 - loss: 0.5765 - val_accuracy: 0.7190 - val_loss: 0.5554
# Epoch 62/100
# 339/339 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7062 - loss: 0.5762 - val_accuracy: 0.7134 - val_loss: 0.5573
# Epoch 63/100
# 339/339 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7026 - loss: 0.5775 - val_accuracy: 0.7127 - val_loss: 0.5571
# Epoch 64/100
# 339/339 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7046 - loss: 0.5756 - val_accuracy: 0.7186 - val_loss: 0.5586
# Epoch 65/100
# 339/339 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7066 - loss: 0.5762 - val_accuracy: 0.7194 - val_loss: 0.5552
# Epoch 66/100
# 339/339 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7075 - loss: 0.5753 - val_accuracy: 0.7179 - val_loss: 0.5557
# Epoch 67/100
# 339/339 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7058 - loss: 0.5770 - val_accuracy: 0.7171 - val_loss: 0.5549
# Epoch 68/100
# 339/339 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7084 - loss: 0.5744 - val_accuracy: 0.7182 - val_loss: 0.5567
# Epoch 69/100
# 339/339 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7045 - loss: 0.5763 - val_accuracy: 0.7201 - val_loss: 0.5543
# Epoch 70/100
# 339/339 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7073 - loss: 0.5755 - val_accuracy: 0.7186 - val_loss: 0.5545
# Epoch 71/100
# 339/339 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7061 - loss: 0.5752 - val_accuracy: 0.7138 - val_loss: 0.5558
# Epoch 72/100
# 339/339 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7074 - loss: 0.5726 - val_accuracy: 0.7230 - val_loss: 0.5580
# Epoch 73/100
# 339/339 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7044 - loss: 0.5752 - val_accuracy: 0.7134 - val_loss: 0.5565
# Epoch 74/100
# 339/339 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7047 - loss: 0.5734 - val_accuracy: 0.7157 - val_loss: 0.5572

# %%
# !pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\rkbhuyan\appdata\local\programs\python\python313\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\rkbhuyan\appdata\local\programs\python\python313\lib\site-packages (from seaborn) (2.4.4)
# Requirement already satisfied: pandas>=1.2 in c:\users\rkbhuyan\appdata\local\programs\python\python313\lib\site-packages (from seaborn) (3.0.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\rkbhuyan\appdata\local\programs\python\python313\lib\site-packages (from seaborn) (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\rkbhuyan\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\rkbhuyan\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\rkbhuyan\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\rkbhuyan\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\rkbhuyan\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (26.0)
# Requirement already satisfied: pillow>=8 in c:\users\rkbhuyan\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\rkbhuyan\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\rkbhuyan\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\rkbhuyan\appdata\local\programs\python\python313\lib\site-packages (from pandas>=1.2->seaborn) (2026.1)
# Requirement already satisfied: six>=1.5 in c:\users\rkbhuyan\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Plotting the model accuracy 
import seaborn as sns
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show(block=True)

# %%
loss, accuracy = model.evaluate(X_test, Y_test)
print(f"\nModel Accuracy: {accuracy:.4f}")
# Out:
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7201 - loss: 0.5543
#
# Model Accuracy: 0.7201

# %%
X_train
# Out:
# array([[ 0.36961402,  0.20209691, -0.7046317 ],
#        [ 0.0310906 ,  0.56110332, -0.7046317 ],
#        [ 0.49467961,  0.56110332,  0.59050155],
#        ...,
#        [ 0.65594841, -0.87492235, -0.7046317 ],
#        [ 0.5887139 ,  0.56110332, -0.7046317 ],
#        [ 0.09879528, -0.87492235,  0.59050155]], shape=(10830, 3))

# %%
X_test
# Out:
# array([[ 0.13264762, -0.15690951,  0.59050155],
#        [-0.09961706,  1.63812258, -0.05706508],
#        [ 0.16414911, -1.23392877,  0.59050155],
#        ...,
#        [-0.15180608,  0.20209691, -0.7046317 ],
#        [ 0.18577699,  0.20209691,  0.59050155],
#        [ 0.12935642,  0.56110332,  0.59050155]], shape=(2708, 3))

# %%
Y_train
# Out:
# array([1, 1, 1, ..., 1, 1, 1], shape=(10830,))

# %%
Y_test
# Out:
# array([1, 0, 1, ..., 0, 1, 0], shape=(2708,))

# %%
Y_pred = model.predict(X_test)  # predicting the truck breakdown using our ANN model
Y_pred
# Out:
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# array([[0.65274906],
#        [0.15094543],
#        [0.580415  ],
#        ...,
#        [0.78948045],
#        [0.662078  ],
#        [0.67618716]], shape=(2708, 1), dtype=float32)

# %%
Y_pred_binary = (Y_pred > 0.5).astype(int)
Y_pred_binary
# Out:
# array([[1],
#        [0],
#        [1],
#        ...,
#        [1],
#        [1],
#        [1]], shape=(2708, 1))

# %%
len(Y_pred_binary)
# Out:
# 2708

# %%
indexes_of_0s = np.where(Y_pred_binary == 0)[0]
indexes_of_1s = np.where(Y_pred_binary == 1)[0]

# %%
indexes_of_0s
# Out:
# array([   1,    5,   22,   25,   26,   35,   38,   48,   52,   60,   66,
#          79,   81,   87,   88,  109,  117,  120,  124,  130,  145,  166,
#         169,  171,  174,  185,  194,  203,  205,  206,  208,  217,  222,
#         227,  231,  233,  242,  256,  267,  268,  269,  272,  276,  278,
#         302,  308,  352,  360,  367,  371,  372,  378,  399,  404,  406,
#         419,  424,  429,  436,  437,  445,  446,  456,  479,  480,  491,
#         494,  500,  506,  507,  515,  520,  532,  533,  577,  579,  596,
#         611,  613,  623,  627,  631,  635,  639,  641,  644,  651,  652,
#         653,  654,  699,  705,  707,  718,  722,  741,  745,  749,  760,
#         774,  788,  789,  794,  806,  808,  809,  814,  824,  825,  827,
#         836,  841,  846,  848,  851,  862,  866,  871,  874,  876,  887,
#         896,  901,  907,  912,  913,  930,  951,  953,  956,  975,  979,
#         986,  988,  992, 1005, 1006, 1026, 1029, 1030, 1032, 1034, 1039,
#        1042, 1055, 1063, 1070, 1077, 1079, 1085, 1090, 1095, 1101, 1102,
#        1104, 1105, 1116, 1117, 1132, 1139, 1142, 1158, 1171, 1185, 1202,
#        1214, 1218, 1228, 1232, 1236, 1243, 1252, 1258, 1304, 1316, 1329,
#        1332, 1337, 1345, 1352, 1358, 1362, 1382, 1385, 1402, 1404, 1408,
#        1412, 1421, 1423, 1429, 1431, 1442, 1444, 1447, 1455, 1464, 1466,
#        1505, 1512, 1513, 1523, 1525, 1535, 1540, 1541, 1549, 1552, 1554,
#        1558, 1569, 1573, 1589, 1593, 1596, 1597, 1611, 1616, 1628, 1636,
#        1643, 1645, 1648, 1651, 1671, 1689, 1690, 1695, 1706, 1709, 1718,
#        1727, 1735, 1745, 1752, 1756, 1757, 1774, 1781, 1788, 1792, 1797,
#        1800, 1811, 1830, 1831, 1843, 1847, 1859, 1861, 1864, 1869, 1870,
#        1906, 1916, 1917, 1918, 1928, 1938, 1944, 1954, 1956, 1957, 1959,
#        1961, 1983, 1990, 2000, 2007, 2011, 2022, 2033, 2038, 2055, 2060,
#        2082, 2091, 2092, 2096, 2101, 2102, 2108, 2113, 2116, 2119, 2124,
#        2131, 2162, 2168, 2171, 2176, 2178, 2198, 2208, 2220, 2232, 2239,
#        2250, 2254, 2255, 2274, 2287, 2299, 2309, 2317, 2337, 2343, 2348,
#        2350, 2367, 2368, 2373, 2380, 2392, 2393, 2399, 2406, 2413, 2416,
#        2418, 2427, 2430, 2446, 2452, 2457, 2474, 2478, 2487, 2490, 2496,
#        2503, 2508, 2521, 2525, 2531, 2549, 2551, 2569, 2573, 2576, 2583,
#        2595, 2605, 2607, 2608, 2625, 2634, 2635, 2642, 2645, 2661, 2672,
#        2675, 2678, 2679, 2683, 2689, 2693])

# %%
indexes_of_1s
# Out:
# array([   0,    2,    3, ..., 2705, 2706, 2707], shape=(2350,))

# %%
Y_pred_binary[2637]
# Out:
# array([1])

# %%
df_Y_pred = pd.DataFrame(Y_pred_binary, columns=['description'])
df_Y_pred
# Out:
#       description
# 0               1
# 1               0
# 2               1
# 3               1
# 4               1
# ...           ...
# 2703            1
# 2704            1
# 2705            1
# 2706            1
# 2707            1
#
# [2708 rows x 1 columns]

# %%
X_test_original = scaler.inverse_transform(X_test)  # Decoding the test features into its original values
X_test_original
# Out:
# array([[98.36, 18.  ,  0.  ],
#        [93.42, 36.  , -1.  ],
#        [99.03,  7.2 ,  0.  ],
#        ...,
#        [92.31, 21.6 , -2.  ],
#        [99.49, 21.6 ,  0.  ],
#        [98.29, 25.2 ,  0.  ]], shape=(2708, 3))

# %%
df_feature_original = pd.DataFrame(X_test_original, columns=['tonnage_percentage', 'speed', 'gradient'])
df_feature_original
# Out:
#       tonnage_percentage  speed  gradient
# 0                  98.36   18.0       0.0
# 1                  93.42   36.0      -1.0
# 2                  99.03    7.2       0.0
# 3                  98.91   18.0      -2.0
# 4                 102.57   21.6       0.0
# ...                  ...    ...       ...
# 2703              100.89   25.2      -2.0
# 2704              105.43   32.4      -2.0
# 2705               92.31   21.6      -2.0
# 2706               99.49   21.6       0.0
# 2707               98.29   25.2       0.0
#
# [2708 rows x 3 columns]

# %%
df_test = pd.concat([df_feature_original, df_Y_pred], axis=1)
df_test
# Out:
#       tonnage_percentage  speed  gradient  description
# 0                  98.36   18.0       0.0            1
# 1                  93.42   36.0      -1.0            0
# 2                  99.03    7.2       0.0            1
# 3                  98.91   18.0      -2.0            1
# 4                 102.57   21.6       0.0            1
# ...                  ...    ...       ...          ...
# 2703              100.89   25.2      -2.0            1
# 2704              105.43   32.4      -2.0            1
# 2705               92.31   21.6      -2.0            1
# 2706               99.49   21.6       0.0            1
# 2707               98.29   25.2       0.0            1
#
# [2708 rows x 4 columns]

# %%
plt.hist(df_test['description'], bins=20)
plt.xlabel('Predicted Probability')
plt.ylabel('Frequency')
plt.title('Distribution of Predicted Probabilities')
plt.show(block=True)

# %%
mapping_dict = {0: 'Cannot cause tire breakdown', 1: 'Could cause tire breakdown'}

# %%
df_test['description'] = df_test['description'].map(mapping_dict)  # Classifying our description values into meanigful mappings
df_test
# Out:
#       tonnage_percentage  speed  gradient                  description
# 0                  98.36   18.0       0.0   Could cause tire breakdown
# 1                  93.42   36.0      -1.0  Cannot cause tire breakdown
# 2                  99.03    7.2       0.0   Could cause tire breakdown
# 3                  98.91   18.0      -2.0   Could cause tire breakdown
# 4                 102.57   21.6       0.0   Could cause tire breakdown
# ...                  ...    ...       ...                          ...
# 2703              100.89   25.2      -2.0   Could cause tire breakdown
# 2704              105.43   32.4      -2.0   Could cause tire breakdown
# 2705               92.31   21.6      -2.0   Could cause tire breakdown
# 2706               99.49   21.6       0.0   Could cause tire breakdown
# 2707               98.29   25.2       0.0   Could cause tire breakdown
#
# [2708 rows x 4 columns]

# %% [markdown]
# MODEL PERFORMANCE METRICS

# %%
from sklearn.metrics import confusion_matrix, classification_report, precision_score, recall_score, f1_score

# %%
Y_pred_binary
# Out:
# array([[1],
#        [0],
#        [1],
#        ...,
#        [1],
#        [1],
#        [1]], shape=(2708, 1))

# %%
Y_test
# Out:
# array([1, 0, 1, ..., 0, 1, 0], shape=(2708,))

# %%
# CONFUSION MATRIX
import numpy as np

cm = confusion_matrix(Y_test, Y_pred_binary)

cm_percent = cm / cm.sum(axis=1, keepdims=True)

plt.figure(figsize=(6,5))
sns.heatmap(cm_percent, 
            annot=True, 
            fmt=".2f", 
            cmap='Blues',
            xticklabels=["No Risk", "Risk"],
            yticklabels=["No Risk", "Risk"])

plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

# %%
precision = precision_score(Y_test, Y_pred_binary)
recall = recall_score(Y_test, Y_pred_binary)
f1 = f1_score(Y_test, Y_pred_binary)

print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"F1 Score: {f1:.2f}")
# Out:
# Precision: 0.71
# Recall: 0.95
# F1 Score: 0.82

# %%
print(classification_report(Y_test, Y_pred_binary))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.29      0.42       958
#            1       0.71      0.95      0.82      1750
#
#     accuracy                           0.72      2708
#    macro avg       0.75      0.62      0.62      2708
# weighted avg       0.74      0.72      0.68      2708

# %%
import joblib

joblib.dump(model, "dump_model.pkl")
joblib.dump(scaler, "scaler_dump.pkl")
# Out:
# ['scaler_dump.pkl']
